# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\mano2\\Desktop\\Python\\PW Skills\\zomato.csv\\zomato.csv")

# %%
df.head(2)
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
#
#                                              address            name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...           Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...  Spice Elephant
#
#   online_order book_table   rate  votes                           phone  \
# 0          Yes        Yes  4.1/5    775  080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                    080 41714161
#
#        location      rest_type  \
# 0  Banashankari  Casual Dining
# 1  Banashankari  Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
#
#                          cuisines approx_cost(for two people)  \
# ...

# %%
df.drop(columns=["url","address"], inplace=True)

# %%
df.head(2)
# Out:
#              name online_order book_table   rate  votes  \
# 0           Jalsa          Yes        Yes  4.1/5    775
# 1  Spice Elephant          Yes         No  4.1/5    787
#
#                             phone      location      rest_type  \
# 0  080 42297555\r\n+91 9743772233  Banashankari  Casual Dining
# 1                    080 41714161  Banashankari  Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
# 1     Chinese, North Indian, Thai                         800
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
#
#   listed_in(type) listed_in(city)
# ...

# %%
df.drop(columns=["phone","dish_liked","cuisines","reviews_list","menu_item"],inplace=True)

# %%
df.head(2)
# Out:
#              name online_order book_table   rate  votes      location  \
# 0           Jalsa          Yes        Yes  4.1/5    775  Banashankari
# 1  Spice Elephant          Yes         No  4.1/5    787  Banashankari
#
#        rest_type approx_cost(for two people) listed_in(type) listed_in(city)
# 0  Casual Dining                         800          Buffet    Banashankari
# 1  Casual Dining                         800          Buffet    Banashankari

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         51717 non-null  object
#  1   online_order                 51717 non-null  object
#  2   book_table                   51717 non-null  object
#  3   rate                         43942 non-null  object
#  4   votes                        51717 non-null  int64
#  5   location                     51696 non-null  object
#  6   rest_type                    51490 non-null  object
#  7   approx_cost(for two people)  51371 non-null  object
#  8   listed_in(type)              51717 non-null  object
#  9   listed_in(city)              51717 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 3.9+ MB

# %%
df.isnull().sum()
# Out:
# name                              0
# online_order                      0
# book_table                        0
# rate                           7775
# votes                             0
# location                         21
# rest_type                       227
# approx_cost(for two people)     346
# listed_in(type)                   0
# listed_in(city)                   0
# dtype: int64

# %%
df['rate']=df['rate'].str.split('/').str.get(0)

# %%
df.head()
# Out:
#                     name online_order book_table rate  votes      location  \
# 0                  Jalsa          Yes        Yes  4.1    775  Banashankari
# 1         Spice Elephant          Yes         No  4.1    787  Banashankari
# 2        San Churro Cafe          Yes         No  3.8    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No  3.7     88  Banashankari
# 4          Grand Village           No         No  3.8    166  Basavanagudi
#
#              rest_type approx_cost(for two people) listed_in(type)  \
# 0        Casual Dining                         800          Buffet
# 1        Casual Dining                         800          Buffet
# 2  Cafe, Casual Dining                         800          Buffet
# 3          Quick Bites                         300          Buffet
# 4        Casual Dining                         600          Buffet
#
#   listed_in(city)
# 0    Banashankari
# 1    Banashankari
# 2    Banashankari
# 3    Banashankari
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         51717 non-null  object
#  1   online_order                 51717 non-null  object
#  2   book_table                   51717 non-null  object
#  3   rate                         43942 non-null  object
#  4   votes                        51717 non-null  int64
#  5   location                     51696 non-null  object
#  6   rest_type                    51490 non-null  object
#  7   approx_cost(for two people)  51371 non-null  object
#  8   listed_in(type)              51717 non-null  object
#  9   listed_in(city)              51717 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 3.9+ MB

# %%
df.isnull().sum()
# Out:
# name                              0
# online_order                      0
# book_table                        0
# rate                           7775
# votes                             0
# location                         21
# rest_type                       227
# approx_cost(for two people)     346
# listed_in(type)                   0
# listed_in(city)                   0
# dtype: int64

# %%
df["rate"].fillna(df["rate"].mean, inplace=True)

# %%
df.isnull().sum()
# Out:
# name                             0
# online_order                     0
# book_table                       0
# rate                             0
# votes                            0
# location                        21
# rest_type                      227
# approx_cost(for two people)    346
# listed_in(type)                  0
# listed_in(city)                  0
# dtype: int64

# %%
df["rest_type"].value_counts()
# Out:
# rest_type
# Quick Bites                   19132
# Casual Dining                 10330
# Cafe                           3732
# Delivery                       2604
# Dessert Parlor                 2263
#                               ...
# Dessert Parlor, Kiosk             2
# Food Court, Beverage Shop         2
# Dessert Parlor, Food Court        2
# Sweet Shop, Dessert Parlor        1
# Quick Bites, Kiosk                1
# Name: count, Length: 93, dtype: int64

# %%
df["rest_type"]=df["rest_type"].str.split(',').str.get(0)

# %%
df.head()
# Out:
#                     name online_order book_table rate  votes      location  \
# 0                  Jalsa          Yes        Yes  4.1    775  Banashankari
# 1         Spice Elephant          Yes         No  4.1    787  Banashankari
# 2        San Churro Cafe          Yes         No  3.8    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No  3.7     88  Banashankari
# 4          Grand Village           No         No  3.8    166  Basavanagudi
#
#        rest_type approx_cost(for two people) listed_in(type) listed_in(city)
# 0  Casual Dining                         800          Buffet    Banashankari
# 1  Casual Dining                         800          Buffet    Banashankari
# 2           Cafe                         800          Buffet    Banashankari
# 3    Quick Bites                         300          Buffet    Banashankari
# 4  Casual Dining                         600          Buffet    Banashankari

# %%
df["rest_type"].value_counts()
# Out:
# rest_type
# Quick Bites       19521
# Casual Dining     12026
# Cafe               4364
# Dessert Parlor     2744
# Delivery           2604
# Takeaway           2157
# Bakery             1689
# Beverage Shop      1272
# Bar                1155
# Pub                 776
# Food Court          740
# Sweet Shop          647
# Lounge              501
# Fine Dining         405
# Mess                270
# Microbrewery        226
# Kiosk               176
# Food Truck           84
# Confectionery        47
# Club                 41
# Dhaba                40
# Bhojanalya            3
# Pop Up                2
# Name: count, dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (51607, 10)

# %%
df["location"].value_counts()
# Out:
# location
# BTM                      5109
# HSR                      2521
# Koramangala 5th Block    2502
# JP Nagar                 2234
# Whitefield               2140
#                          ...
# West Bangalore              6
# Yelahanka                   6
# Jakkur                      3
# Rajarajeshwari Nagar        2
# Peenya                      1
# Name: count, Length: 93, dtype: int64

# %%
df["listed_in(city)"].value_counts()
# Out:
# listed_in(city)
# BTM                      3266
# Koramangala 7th Block    2935
# Koramangala 5th Block    2832
# Koramangala 4th Block    2777
# Koramangala 6th Block    2622
# Jayanagar                2365
# JP Nagar                 2095
# Indiranagar              1856
# MG Road                  1806
# Church Street            1793
# Brigade Road             1768
# Lavelle Road             1741
# HSR                      1740
# Marathahalli             1657
# Residency Road           1619
# Whitefield               1617
# Bannerghatta Road        1616
# Brookefield              1517
# Old Airport Road         1422
# Kammanahalli             1326
# Kalyan Nagar             1305
# Basavanagudi             1266
# Sarjapur Road            1259
# Electronic City          1225
# Bellandur                1222
# Frazer Town              1185
# Malleshwaram             1095
# Rajajinagar              1078
# Banashankari              862
# New BEL Road              740
# ...

# %%
df.head()
# Out:
#                     name online_order book_table rate  votes      location  \
# 0                  Jalsa          Yes        Yes  4.1    775  Banashankari
# 1         Spice Elephant          Yes         No  4.1    787  Banashankari
# 2        San Churro Cafe          Yes         No  3.8    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No  3.7     88  Banashankari
# 4          Grand Village           No         No  3.8    166  Basavanagudi
#
#        rest_type approx_cost(for two people) listed_in(type) listed_in(city)
# 0  Casual Dining                         800          Buffet    Banashankari
# 1  Casual Dining                         800          Buffet    Banashankari
# 2           Cafe                         800          Buffet    Banashankari
# 3    Quick Bites                         300          Buffet    Banashankari
# 4  Casual Dining                         600          Buffet    Banashankari

# %%
df.isnull().sum()
# Out:
# name                             0
# online_order                     0
# book_table                       0
# rate                             0
# votes                            0
# location                        21
# rest_type                      227
# approx_cost(for two people)    344
# listed_in(type)                  0
# listed_in(city)                  0
# dtype: int64

# %%
df["approx_cost(for two people)"].fillna(df["approx_cost(for two people)"].mean, inplace=True)

# %%
df.isnull().sum()
# Out:
# name                             0
# online_order                     0
# book_table                       0
# rate                             0
# votes                            0
# location                        21
# rest_type                      227
# approx_cost(for two people)      0
# listed_in(type)                  0
# listed_in(city)                  0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# location                       0
# rest_type                      0
# approx_cost(for two people)    0
# listed_in(type)                0
# listed_in(city)                0
# dtype: int64

# %%
df.shape
# Out:
# (51380, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51380 entries, 0 to 51716
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         51380 non-null  object
#  1   online_order                 51380 non-null  object
#  2   book_table                   51380 non-null  object
#  3   rate                         51380 non-null  object
#  4   votes                        51380 non-null  int64
#  5   location                     51380 non-null  object
#  6   rest_type                    51380 non-null  object
#  7   approx_cost(for two people)  51380 non-null  object
#  8   listed_in(type)              51380 non-null  object
#  9   listed_in(city)              51380 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 4.3+ MB

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df["listed_in(type)"]=le.fit_transform(df["listed_in(type)"])

# %%
df.head()
# Out:
#                     name online_order book_table rate  votes      location  \
# 0                  Jalsa          Yes        Yes  4.1    775  Banashankari
# 1         Spice Elephant          Yes         No  4.1    787  Banashankari
# 2        San Churro Cafe          Yes         No  3.8    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No  3.7     88  Banashankari
# 4          Grand Village           No         No  3.8    166  Basavanagudi
#
#        rest_type approx_cost(for two people)  listed_in(type) listed_in(city)
# 0  Casual Dining                         800                0    Banashankari
# 1  Casual Dining                         800                0    Banashankari
# 2           Cafe                         800                0    Banashankari
# 3    Quick Bites                         300                0    Banashankari
# 4  Casual Dining                         600                0    Banashankari

# %%
df["listed_in(city)"]=le.fit_transform(df["listed_in(city)"])

# %%
df.head()
# Out:
#                     name online_order book_table rate  votes      location  \
# 0                  Jalsa          Yes        Yes  4.1    775  Banashankari
# 1         Spice Elephant          Yes         No  4.1    787  Banashankari
# 2        San Churro Cafe          Yes         No  3.8    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No  3.7     88  Banashankari
# 4          Grand Village           No         No  3.8    166  Basavanagudi
#
#        rest_type approx_cost(for two people)  listed_in(type)  listed_in(city)
# 0  Casual Dining                         800                0                1
# 1  Casual Dining                         800                0                1
# 2           Cafe                         800                0                1
# 3    Quick Bites                         300                0                1
# 4  Casual Dining                         600                0                1

# %%
df["rest_type"]=le.fit_transform(df["rest_type"])
df.head()
# Out:
#                     name online_order book_table rate  votes      location  \
# 0                  Jalsa          Yes        Yes  4.1    775  Banashankari
# 1         Spice Elephant          Yes         No  4.1    787  Banashankari
# 2        San Churro Cafe          Yes         No  3.8    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No  3.7     88  Banashankari
# 4          Grand Village           No         No  3.8    166  Basavanagudi
#
#    rest_type approx_cost(for two people)  listed_in(type)  listed_in(city)
# 0          5                         800                0                1
# 1          5                         800                0                1
# 2          4                         800                0                1
# 3         20                         300                0                1
# 4          5                         600                0                1

# %%
df.head(10)
# Out:
#                                               name online_order book_table  \
# 0                                            Jalsa          Yes        Yes
# 1                                   Spice Elephant          Yes         No
# 2                                  San Churro Cafe          Yes         No
# 3                            Addhuri Udupi Bhojana           No         No
# 4                                    Grand Village           No         No
# 5                                  Timepass Dinner          Yes         No
# 6  Rosewood International Hotel - Bar & Restaurant           No         No
# 7                                           Onesta          Yes        Yes
# 8                                   Penthouse Cafe          Yes         No
# 9                                        Smacznego          Yes         No
#
#   rate  votes      location  rest_type approx_cost(for two people)  \
# 0  4.1    775  Banashankari          5                         800
# ...

# %%
df["location"]=le.fit_transform(df["location"])

# %%
df["book_table"]=le.fit_transform(df["book_table"])

# %%
df.head()
# Out:
#                     name online_order  book_table rate  votes  location  \
# 0                  Jalsa          Yes           1  4.1    775         1
# 1         Spice Elephant          Yes           0  4.1    787         1
# 2        San Churro Cafe          Yes           0  3.8    918         1
# 3  Addhuri Udupi Bhojana           No           0  3.7     88         1
# 4          Grand Village           No           0  3.8    166         4
#
#    rest_type approx_cost(for two people)  listed_in(type)  listed_in(city)
# 0          5                         800                0                1
# 1          5                         800                0                1
# 2          4                         800                0                1
# 3         20                         300                0                1
# 4          5                         600                0                1

# %%
df["online_order"]=le.fit_transform(df["online_order"])

# %%
df.head()
# Out:
#                     name  online_order  book_table rate  votes  location  \
# 0                  Jalsa             1           1  4.1    775         1
# 1         Spice Elephant             1           0  4.1    787         1
# 2        San Churro Cafe             1           0  3.8    918         1
# 3  Addhuri Udupi Bhojana             0           0  3.7     88         1
# 4          Grand Village             0           0  3.8    166         4
#
#    rest_type approx_cost(for two people)  listed_in(type)  listed_in(city)
# 0          5                         800                0                1
# 1          5                         800                0                1
# 2          4                         800                0                1
# 3         20                         300                0                1
# 4          5                         600                0                1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51380 entries, 0 to 51716
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         51380 non-null  object
#  1   online_order                 51380 non-null  int32
#  2   book_table                   51380 non-null  int32
#  3   rate                         51380 non-null  object
#  4   votes                        51380 non-null  int64
#  5   location                     51380 non-null  int32
#  6   rest_type                    51380 non-null  int32
#  7   approx_cost(for two people)  51380 non-null  object
#  8   listed_in(type)              51380 non-null  int32
#  9   listed_in(city)              51380 non-null  int32
# dtypes: int32(6), int64(1), object(3)
# memory usage: 3.1+ MB

# %%
df["approx_cost(for two people)"]=df["approx_cost(for two people)"].str.replace(",","")

# %%
df["approx_cost(for two people)"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='approx_cost(for two people)'>

# %%
df.isnull().sum()
# Out:
# name                             0
# online_order                     0
# book_table                       0
# rate                             0
# votes                            0
# location                         0
# rest_type                        0
# approx_cost(for two people)    321
# listed_in(type)                  0
# listed_in(city)                  0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# location                       0
# rest_type                      0
# approx_cost(for two people)    0
# listed_in(type)                0
# listed_in(city)                0
# dtype: int64

# %%
df["approx_cost(for two people)"].astype(int)
# Out:
# 0         800
# 1         800
# 2         800
# 3         300
# 4         600
#          ...
# 51712    1500
# 51713     600
# 51714    2000
# 51715    2500
# 51716    1500
# Name: approx_cost(for two people), Length: 51059, dtype: int32

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51059 entries, 0 to 51716
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         51059 non-null  object
#  1   online_order                 51059 non-null  int32
#  2   book_table                   51059 non-null  int32
#  3   rate                         51059 non-null  object
#  4   votes                        51059 non-null  int64
#  5   location                     51059 non-null  int32
#  6   rest_type                    51059 non-null  int32
#  7   approx_cost(for two people)  51059 non-null  object
#  8   listed_in(type)              51059 non-null  int32
#  9   listed_in(city)              51059 non-null  int32
# dtypes: int32(6), int64(1), object(3)
# memory usage: 3.1+ MB

# %%
df["rate"]=df["rate"].str.replace("NaN","")

# %%
df.isnull().sum()
# Out:
# name                              0
# online_order                      0
# book_table                        0
# rate                           7604
# votes                             0
# location                          0
# rest_type                         0
# approx_cost(for two people)       0
# listed_in(type)                   0
# listed_in(city)                   0
# dtype: int64

# %%
df["rate"].fillna(df["rate"].mean, inplace=True)

# %%
df.isnull().sum()
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# location                       0
# rest_type                      0
# approx_cost(for two people)    0
# listed_in(type)                0
# listed_in(city)                0
# dtype: int64

# %%
df["rate"]=df["rate"].str.replace("NEW","")

# %%
df.isnull().sum()
# Out:
# name                              0
# online_order                      0
# book_table                        0
# rate                           7604
# votes                             0
# location                          0
# rest_type                         0
# approx_cost(for two people)       0
# listed_in(type)                   0
# listed_in(city)                   0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (43455, 10)

# %%
df.isnull().sum()
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# location                       0
# rest_type                      0
# approx_cost(for two people)    0
# listed_in(type)                0
# listed_in(city)                0
# dtype: int64

# %%
df["rate"].value_counts().plot(kind= 'bar')
# Out:
# <Axes: xlabel='rate'>

# %%
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51709    False
# 51711    False
# 51712    False
# 51715    False
# 51716    False
# Name: rate, Length: 43455, dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43455 entries, 0 to 51716
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         43455 non-null  object
#  1   online_order                 43455 non-null  int32
#  2   book_table                   43455 non-null  int32
#  3   rate                         43455 non-null  object
#  4   votes                        43455 non-null  int64
#  5   location                     43455 non-null  int32
#  6   rest_type                    43455 non-null  int32
#  7   approx_cost(for two people)  43455 non-null  object
#  8   listed_in(type)              43455 non-null  int32
#  9   listed_in(city)              43455 non-null  int32
# dtypes: int32(6), int64(1), object(3)
# memory usage: 2.7+ MB

# %%
df["rate"]=df["rate"].str.replace("''","")

# %%
df.isnull().sum()
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# location                       0
# rest_type                      0
# approx_cost(for two people)    0
# listed_in(type)                0
# listed_in(city)                0
# dtype: int64

# %%
df["online_order"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='online_order'>

# %%
df["book_table"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='book_table'>

# %%
df["rate"]=pd.to_numeric(df['rate'], errors='coerce')

# %%
df.isnull().sum()
# Out:
# name                              0
# online_order                      0
# book_table                        0
# rate                           2257
# votes                             0
# location                          0
# rest_type                         0
# approx_cost(for two people)       0
# listed_in(type)                   0
# listed_in(city)                   0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop(columns=["name","rate"])

# %%
y=df["rate"]

# %%
y
# Out:
# 0        4.1
# 1        4.1
# 2        3.8
# 3        3.7
# 4        3.8
#         ...
# 51709    3.7
# 51711    2.5
# 51712    3.6
# 51715    4.3
# 51716    3.4
# Name: rate, Length: 41198, dtype: float64

# %%
df.shape
# Out:
# (41198, 10)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.2918738788717289

# %%
df["rate"].hist(bins=20)
# Out:
# <Axes: >

# %%
from sklearn.ensemble import BaggingRegressor

# %%
bag=BaggingRegressor()

# %%
bag.fit(x_train,y_train)
# Out:
# BaggingRegressor()

# %%
bag.score(x_test,y_test)
# Out:
# 0.8467500917698926

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf=RandomForestRegressor()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rf.score(x_test,y_test)
# Out:
# 0.8663715274084725

# %%
from sklearn.metrics import r2_score

# %%
y_pred=rf.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8663715274084725

# %%
y_p=bag.predict(x_test)

# %%
r2_score(y_test,y_p)
# Out:
# 0.8467500917698926
